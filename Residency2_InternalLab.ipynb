# %% [markdown]
# # K nearest neighbors

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x, y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h: X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Overview
#
# 1. Read the problem statement.
#
# 2. Get the dataset.
#
# 3. Explore the dataset.
#
# 4. Pre-processing of dataset.
#
# 5. Visualization
#
# 6. Transform the dataset for building machine learning model.
#
# 7. Split data into train, test set.
#
# 8. Build Model.
#
# 9. Apply the model.
#
# 10. Evaluate the model.
#
# 11. Finding Optimal K value
#
# 12. Repeat 7, 8, 9 steps.

# %% [markdown]
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Download the dataset here:**
# - https://www.kaggle.com/uciml/iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Load data

# %%
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import seaborn           as sns

# %%
iris_df=pd.read_csv("iris (1).csv")

# %% [markdown]
# ### Question 1
#
# Import the data set and print 10 random rows from the data set
#
# Hint: use **sample()** function to get random rows

# %%
iris_df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 136  137            6.3           3.4            5.6           2.4
# 95    96            5.7           3.0            4.2           1.2
# 0      1            5.1           3.5            1.4           0.2
# 22    23            4.6           3.6            1.0           0.2
# 126  127            6.2           2.8            4.8           1.8
# 12    13            4.8           3.0            1.4           0.1
# 99   100            5.7           2.8            4.1           1.3
# 48    49            5.3           3.7            1.5           0.2
# 19    20            5.1           3.8            1.5           0.3
# 90    91            5.5           2.6            4.4           1.2
#
#              Species
# 136   Iris-virginica
# 95   Iris-versicolor
# 0        Iris-setosa
# 22       Iris-setosa
# 126   Iris-virginica
# 12       Iris-setosa
# 99   Iris-versicolor
# 48       Iris-setosa
# 19       Iris-setosa
# 90   Iris-versicolor

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Question 2 - Estimating missing values
#
# Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median)

# %% [markdown]
# Calculate the number of missing values per column
# - don't use loops

# %% [markdown]
# Fill missing values with median of that particular column

# %% [markdown]
# ### Question 3 - Dealing with categorical data
#
# Change all the classes to numericals (0 to 2)
#
# Hint: use **LabelEncoder()**

# %% [markdown]
# ### Question 4
#
# Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.
#
# Hint: use **corr()**

# %% [markdown]
# ### Question 5
#
# Observe the independent variables variance and drop such variables having no variance or almost zero variance (variance < 0.1). They will be having almost no influence on the classification
#
# Hint: use **var()**

# %% [markdown]
# ### Question 6
#
# Plot the scatter matrix for all the variables.
#
# Hint: use **pandas.plotting.scatter_matrix()**
#
# you can also use pairplot()

# %% [markdown]
# ## Split the dataset into training and test sets

# %% [markdown]
# ### Question 7
#
# Split the dataset into training and test sets with 80-20 ratio
#
# Hint: use **train_test_split()**

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 8
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %% [markdown]
# ## Find optimal value of K

# %% [markdown]
# ### Question 9 - Finding Optimal value of k
#
# - Run the KNN with no of neighbours to be 1, 3, 5 ... 19
# - Find the **optimal number of neighbours** from the above list

# %% [markdown]
# ## Plot accuracy

# %% [markdown]
# ### Question 10
#
# Plot accuracy score vs k (with k value on X-axis) using matplotlib.

# %% [markdown]
# # Breast cancer dataset

# %% [markdown]
# ## Read data

# %% [markdown]
# ### Question 1
# Read the data given in bc2.csv file

# %%
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import seaborn           as sns

bc_df=pd.read_csv("bc2.csv")
bc_df
# Out:
#           ID  ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0    1000025               5          1           1                  1
# 1    1002945               5          4           4                  5
# 2    1015425               3          1           1                  1
# 3    1016277               6          8           8                  1
# 4    1017023               4          1           1                  3
# 5    1017122               8         10          10                  8
# 6    1018099               1          1           1                  1
# 7    1018561               2          1           2                  1
# 8    1033078               2          1           1                  1
# 9    1033078               4          2           1                  1
# 10   1035283               1          1           1                  1
# 11   1036172               2          1           1                  1
# 12   1041801               5          3           3                  3
# 13   1043999               1          1           1                  1
# 14   1044572               8          7           5                 10
# 15   1047630               7          4           6                  4
# 16   1048672               4          1           1                  1
# 17   1049815               4          1           1                  1
# 18   1050670              10          7           7                  6
# 19   1050718               6          1           1                  1
# 20   1054590               7          3           2                 10
# 21   1054593              10          5           5                  3
# 22   1056784               3          1           1                  1
# 23   1057013               8          4           5                  1
# 24   1059552               1          1           1                  1
# 25   1065726               5          2           3                  4
# 26   1066373               3          2           1                  1
# 27   1066979               5          1           1                  1
# 28   1067444               2          1           1                  1
# 29   1070935               1          1           3                  1
# ..       ...             ...        ...         ...                ...
# 669  1350423               5         10          10                  8
# 670  1352848               3         10           7                  8
# 671  1353092               3          2           1                  2
# 672  1354840               2          1           1                  1
# 673  1354840               5          3           2                  1
# 674  1355260               1          1           1                  1
# 675  1365075               4          1           4                  1
# 676  1365328               1          1           2                  1
# 677  1368267               5          1           1                  1
# 678  1368273               1          1           1                  1
# 679  1368882               2          1           1                  1
# 680  1369821              10         10          10                 10
# 681  1371026               5         10          10                 10
# 682  1371920               5          1           1                  1
# 683   466906               1          1           1                  1
# 684   466906               1          1           1                  1
# 685   534555               1          1           1                  1
# 686   536708               1          1           1                  1
# 687   566346               3          1           1                  1
# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Question 2
# Observe the no.of records in dataset and type of each column

# %%
bc_df.dtypes
# Out:
# ID                              int64
# ClumpThickness                  int64
# Cell Size                       int64
# Cell Shape                      int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Normal Nucleoli                 int64
# Bland Chromatin                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
bc_df.shape
# Out:
# (699, 11)

# %% [markdown]
# ### Question 3
# Use summary statistics to check if missing values, outlier and encoding treament is necessary
#
# Hint: use **describe()**

# %%
bc_df.describe()
# Out:
#                  ID  ClumpThickness   Cell Size  Cell Shape  \
# count  6.990000e+02      699.000000  699.000000  699.000000
# mean   1.071704e+06        4.417740    3.134478    3.207439
# std    6.170957e+05        2.815741    3.051459    2.971913
# min    6.163400e+04        1.000000    1.000000    1.000000
# 25%    8.706885e+05        2.000000    1.000000    1.000000
# 50%    1.171710e+06        4.000000    1.000000    1.000000
# 75%    1.238298e+06        6.000000    5.000000    5.000000
# max    1.345435e+07       10.000000   10.000000   10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Normal Nucleoli  \
# count         699.000000                   699.000000       699.000000
# mean            2.806867                     3.216023         3.437768
# std             2.855379                     2.214300         2.438364
# min             1.000000                     1.000000         1.000000
# 25%             1.000000                     2.000000         2.000000
# 50%             1.000000                     2.000000         3.000000
# 75%             4.000000                     4.000000         5.000000
# max            10.000000                    10.000000        10.000000
#
#        Bland Chromatin     Mitoses       Class
# count       699.000000  699.000000  699.000000
# mean          2.866953    1.589413    2.689557
# std           3.053634    1.715078    0.951273
# min           1.000000    1.000000    2.000000
# 25%           1.000000    1.000000    2.000000
# 50%           1.000000    1.000000    2.000000
# 75%           4.000000    1.000000    4.000000
# max          10.000000   10.000000    4.000000

# %% [markdown]
# #### Check Missing Values

# %%
bc_df.isnull().sum()
# Out:
# ID                             0
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# ### Question 4
# #### Check how many `?` are there in Bare Nuclei feature (they are also unknown or missing values).

# %%
bc_df['Bare Nuclei'].value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: Bare Nuclei, dtype: int64

# %%
top=bc_df['Bare Nuclei'].describe(include= 'all').top
print(top)
# Out:
# 1

# %% [markdown]
# #### Replace them with the 'top' value of the describe function of Bare Nuclei feature
#
# Hint: give value of parameter include='all' in describe function

# %%
bc_df['Bare Nuclei'].replace('?', top, inplace=True)

# %%
bc_df
# Out:
#           ID  ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 
# 672                            2           1                3
# 673                            3           1                1
# 674                            2           1                2
# 675                            2           1                1
# 676                            2           1                2
# 677                            2           1                1
# 678                            2           1                1
# 679                            2           1                1
# 680                            5          10               10
# 681                            4          10                5
# 682                            2           1                3
# 683                            2           1                1
# 684                            2           1                1
# 685                            2           1                1
# 686                            2           1                1
# 687                            2           1                2
# 688                            2           1                1
# 689                            2           1                1
# 690                            2           1                1
# 691                            4           5                4
# 692                            2           1                1
# 693                            2           1                2
# 694                            3           2                1
# 695                            2           1                1
# 696                            7           3                8
# 697                            3           4               10
# 698                            4           5               10
#
#      Bland Chromatin  Mitoses  Class
# 0                  1        1      2
# 1                  2        1      2
# 2                  1        1      2
# 3                  7        1      2
# 4                  1        1      2
# 5                  7        1      4
# 6                  1        1      2
# 7                  1        1      2
# 8                  1        5      2
# 9                  1        1      2
# 10                 1        1      2
# 11                 1        1      2
# 12                 4        1      4
# 13                 1        1      2
# 14                 5        4      4
# 15                 3        1      4
# 16                 1        1      2
# 17                 1        1      2
# 18                 1        2      4
# 19                 1        1      2
# 20                 4        4      4
# 21                10        1      4
# 22                 1        1      2
# 23                 3        1      4
# 24                 1        1      2
# 25                 6        1      4
# 26                 1        1      2
# 27                 1        1      2
# 28                 1        1      2
# 29                 1        1      2
# ..               ...      ...    ...
# 669               10        1      4
# 670                4        1      4
# 671                1        1      2
# 672                1        1      2
# 673                1        1      2
# 674                1        1      2
# 675                1        1      2
# 676                1        1      2
# 677                1        1      2
# 678                1        1      2
# 679                1        1      2
# 680               10        7      4
# 681                6        3      4
# 682                2        1      2
# 683                1        1      2
# 684                1        1      2
# 685                1        1      2
# 686                1        1      2
# 687                3        1      2
# 688                1        1      2
# 689                1        8      2
# 690                1        1      2
# 691                4        1      4
# 692                1        1      2
# 693                1        2      2
# 694                1        1      2
# 695                1        1      2
# 696               10        2      4
# 697                6        1      4
# 698                4        1      4
#
# [699 rows x 11 columns]

# %% [markdown]
# ### Question 5
# #### Find the distribution of target variable (Class)

# %%
bc_df['Class'].value_counts()
# Out:
# 2    458
# 4    241
# Name: Class, dtype: int64

# %% [markdown]
# #### Plot the distribution of target variable using histogram

# %%
sns.set(rc={'figure.figsize':(10,6)})
bc_df['Class'].plot(kind='hist', legend=True)

# %% [markdown]
# #### Convert the datatype of Bare Nuclei to `int`

# %%
bc_df['Bare Nuclei']=bc_df['Bare Nuclei'].astype(int)
bc_df.dtypes
# Out:
# ID                             int64
# ClumpThickness                 int64
# Cell Size                      int64
# Cell Shape                     int64
# Marginal Adhesion              int64
# Single Epithelial Cell Size    int64
# Bare Nuclei                    int32
# Normal Nucleoli                int64
# Bland Chromatin                int64
# Mitoses                        int64
# Class                          int64
# dtype: object

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# ### Question 6
# Plot Scatter Matrix to understand the distribution of variables and check if any variables are collinear and drop one of them.

# %%
bc_df.drop('ID',axis=1,inplace=True)
sns.pairplot(bc_df)

# %% [markdown]
# ## Train test split

# %% [markdown]
# ### Question 7
# #### Divide the dataset into feature set and target set

# %%
bc_X=bc_df.drop('Class',axis=1)
X=np.array(bc_X)
bc_X.shape
# Out:
# (699, 9)

# %%
bc_Y=bc_df['Class']
Y=np.array(bc_Y)
bc_Y.shape
# Out:
# (699,)

# %% [markdown]
# #### Divide the Training and Test sets in 70:30

# %% [markdown]
# ## Scale the data

# %% [markdown]
# ### Question 8
# Standardize the data
#
# Hint: use **StandardScaler()**

# %%
from sklearn.preprocessing import StandardScaler  
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.3,random_state=1)
scaler = StandardScaler()  
scaler.fit(X_train)

X_train = scaler.transform(X_train)  
X_test = scaler.transform(X_test)

print("X_train is ", X_train)
print("X_test is ", X_test)
# Out:
# X_train is  [[-0.53037642  0.27768679  0.60032199 ...  0.23064162 -0.61180146
#   -0.32064048]
#  [-1.25281115 -0.70629032 -0.75247733 ... -1.03186305  0.03786393
#   -0.32064048]
#  [ 1.99814513  2.24564103  2.29132114 ...  0.23064162  2.31169283
#    5.58370571]
#  ...
#  [-1.25281115 -0.05030558 -0.07607767 ...  1.49314628 -0.28696877
#   -0.32064048]
#  [-0.53037642 -0.70629032  0.26212216 ... -0.19019327 -0.61180146
#   -0.32064048]
#  [ 0.55327568 -0.37829795 -0.75247733 ...  1.49314628 -0.61180146
#   -0.32064048]]
# X_test is  [[ 0.19205831 -0.70629032 -0.75247733 ... -1.03186305 -0.61180146
#   -0.32064048]
#  [-1.25281115 -0.70629032 -0.75247733 ... -0.61102816 -0.61180146
#   -0.32064048]
#  [-0.16915905 -0.70629032 -0.75247733 ... -1.03186305 -0.61180146
#   -0.32064048]
#  ...
#  [-1.25281115 -0.70629032 -0.75247733 ... -0.61102816 -0.61180146
#   -0.32064048]
#  [ 1.27571041 -0.37829795 -0.07607767 ...  1.49314628 -0.61180146
#   -0.32064048]
#  [-1.25281115 -0.70629032 -0.75247733 ... -1.03186305 -0.61180146
#   -0.32064048]]

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 9
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %%
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import accuracy_score
print('k','accuracy')
for i in [3,5,9]:
    classifier = KNeighborsClassifier(n_neighbors=i)  
    classifier.fit(X_train, Y_train)
    Y_pred = classifier.predict(X_test)
    print(i, '-',accuracy_score(Y_test,Y_pred))
# Out:
# k accuracy
# 3 - 0.9666666666666667
# 5 - 0.9809523809523809
# 9 - 0.9666666666666667

# %% [markdown]
# ## Find optimal value of K

# %% [markdown]
# ### Question 10
# Finding Optimal value of k
#
# - Run the KNN with no of neighbours to be 1, 3, 5 ... 19
# - Find the **optimal number of neighbours** from the above list

# %%
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import accuracy_score
k=0
print('k','accuracy')
for i in range(1,20,2):
    classifier = KNeighborsClassifier(n_neighbors=i)  
    classifier.fit(X_train, Y_train)
    Y_pred = classifier.predict(X_test)
    accuracy=accuracy_score(Y_test,Y_pred)
    print(i,accuracy)
    if k <accuracy:
        k=accuracy
        position=i
        
print('optimal value as k',position)
# Out:
# k accuracy
# 1 0.9523809523809523
# 3 0.9666666666666667
# 5 0.9809523809523809
# 7 0.9714285714285714
# 9 0.9666666666666667
# 11 0.9619047619047619
# 13 0.9619047619047619
# 15 0.9619047619047619
# 17 0.9619047619047619
# 19 0.9571428571428572
# optimal value as k 5

# %%
neighbors = np.arange(1, 20,step=2)
train_accuracy_plot = np.empty(len(neighbors))
test_accuracy_plot = np.empty(len(neighbors))
# Loop over different values of k
for i, k in enumerate(neighbors):
    train = []
    test = []
    for j in range(30):
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30,random_state=j)
        sc=StandardScaler()
        scaledX_train = sc.fit_transform(X_train)
        scaledX_test = sc.transform(X_test)
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(scaledX_train,Y_train)
      
        train.append(knn.score(scaledX_train,Y_train))
        test.append(knn.score(scaledX_test,Y_test))

    train_accuracy_plot[i] = np.mean(train)
  
    test_accuracy_plot[i] = np.mean(test)

for i,k in enumerate(neighbors):
    print("K = ",k,": Train accuracy = ",train_accuracy_plot[i],"Test accuracy = ",test_accuracy_plot[i],"Diff=",\
         abs(train_accuracy_plot[i]-test_accuracy_plot[i]))
# Out:
# K =  1 : Train accuracy =  1.0 Test accuracy =  0.953174603174603 Diff= 0.04682539682539699
# K =  3 : Train accuracy =  0.9793456032719838 Test accuracy =  0.9606349206349203 Diff= 0.018710682637063547
# K =  5 : Train accuracy =  0.9728016359918198 Test accuracy =  0.9634920634920634 Diff= 0.009309572499756391
# K =  7 : Train accuracy =  0.970892978868439 Test accuracy =  0.9634920634920634 Diff= 0.00740091537637555
# K =  9 : Train accuracy =  0.9703476482617586 Test accuracy =  0.9644444444444441 Diff= 0.005903203817314462
# K =  11 : Train accuracy =  0.9696659850034081 Test accuracy =  0.9650793650793649 Diff= 0.004586619924043189
# K =  13 : Train accuracy =  0.9691206543967278 Test accuracy =  0.9638095238095237 Diff= 0.005311130587204116
# K =  15 : Train accuracy =  0.9687116564417176 Test accuracy =  0.9638095238095236 Diff= 0.004902132632194078
# K =  17 : Train accuracy =  0.9691206543967279 Test accuracy =  0.9626984126984124 Diff= 0.006422241698315512
# K =  19 : Train accuracy =  0.969256987048398 Test accuracy =  0.9625396825396824 Diff= 0.00671730450871566

# %% [markdown]
# ## Plot accuracy

# %% [markdown]
# ### Question 11
#
# Plot accuracy score vs k (with k value on X-axis) using matplotlib.

# %%
plt.title('k-NN: Varying Number of Neighbors')
plt.plot(neighbors, test_accuracy_plot, label = 'Testing Accuracy')
plt.plot(neighbors, train_accuracy_plot, label = 'Training Accuracy')
plt.legend()
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
